# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("auto.txt")
# print(f"There are {len(words)} total words in the corpus")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 words = read_corpus("auto.txt")
#       2 # print(f"There are {len(words)} total words in the corpus")
#
# Cell In[13], line 2, in read_corpus(filename)
#       1 def read_corpus(filename):
# ----> 2   with open(filename, "r") as file:
#       3     lines = file.readlines()
#       4     words = []
#
# File c:\Users\shara\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'auto.txt'

# %%
vocabs = set(words)
# print(f"There are {len(vocabs)} unique words in the vocabulary")

# %%
word_counts = Counter(words)
print(word_counts["love"])
# Out:
# 58

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["love"])
# Out:
# 0.001810971992381428

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'trasih', 'tfrash', 'traish', 'trasm', 'wtrash', 'tiash', 'trdsh', 'trmsh', 'trosh', 'trasd', 'trasv', 'rtrash', 'trasnh', 'tbash', 'traxsh', 'trarh', 'trashq', 'atrash', 'btrash', 'trajh', 'qrash', 'krash', 'trash', 'trwash', 'trsh', 'trashj', 'trgsh', 'trashs', 'trjash', 'trassh', 'trashf', 'trashk', 'tlash', 'yrash', 'trzsh', 'trasu', 'trashm', 'trjsh', 'trayh', 'trashr', 'trsah', 'trlash', 'tkash', 'trath', 'txash', 'terash', 'urash', 'trasc', 'traqh', 'prash', 'tmrash', 'trasbh', 'trasha', 'trazh', 'traih', 'trasah', 'trasph', 'trbsh', 'traskh', 'gtrash', 'trasp', 'vrash', 'rrash', 'tras', 'trrash', 'trashc', 'ytrash', 'tfash', 'trauh', 'traeh', 'tracsh', 'truash', 'trasrh', 'trasr', 'vtrash', 'trasw', 'txrash', 'trawsh', 'tdash', 'trysh', 'transh', 'hrash', 'trish', 'ktrash', 'tsash', 'trasth', 'trtash', 'trahh', 'trasmh', 'trashb', 'traqsh', 'trass', 'ntrash', 'tqrash', 'trashh', 'toash', 'treash', 'ptrash', 'trasdh', 'traesh', 'trasb', 'trashg', 'trase', 'tnash', 'trcsh', 'trxsh', 'ctrash', 'mtrash', 'strash', 'tnrash', 'troash', 'trqash', 'trashi', 'trashu', 'trasuh', 'zrash', 'turash', 'trasi', 'ltrash', 'twrash', 'trazsh', 'tcash', 'trafsh', 'trasjh', 'trlsh', 'trsash', 'trasxh', 'utrash', 'tarsh', 'tgrash', 'trrsh', 'trasa', 'trasqh', 'twash', 'traoh', 'traxh', 'rtash', 'traswh', 'triash', 'travsh', 'tcrash', 'trasgh', 'trasvh', 'trasg', 'mrash', 'tlrash', 'otrash', 'trdash', 'trxash', 'trakh', 'tash', 'trwsh', 'tralh', 'thrash', 'tgash', 'nrash', 'rash', 'tsrash', 'trasf', 'lrash', 'trzash', 'trashz', 'trasoh', 'trasn', 'tjrash', 'ttash', 'trasho', 'taash', 'tjash', 'trasq', 'tirash', 'trashd', 'traszh', 'traso', 'wrash', 'xtrash', 'trasfh', 'etrash', 'brash', 'tqash', 'tragh', 'tyrash', 'jtrash', 'ftrash', 'dtrash', 'tresh', 'tranh', 'trcash', 'grash', 'trhash', 'trasch', 'trvsh', 'trashe', 'tmash', 'erash', 'trkash', 'tryash', 'tramsh', 'tvrash', 'teash', 'trpsh', 'jrash', 'trfsh', 'trasy', 'trgash', 'traseh', 'traysh', 'thash', 'traph', 'trapsh', 'tzash', 'trarsh', 'trasx', 'trahsh', 'trajsh', 'trahs', 'trtsh', 'ztrash', 'tprash', 'trush', 'trashx', 'trashy', 'trabh', 'trashp', 'drash', 'tvash', 'trafh', 'trasz', 'trasht', 'torash', 'htrash', 'irash', 'trach', 'trawh', 'tpash', 'itrash', 'tzrash', 'trah', 'xrash', 'traslh', 'ttrash', 'tradsh', 'tramh', 'orash', 'arash', 'srash', 'traash', 'trbash', 'trnsh', 'tarash', 'trssh', 'trashl', 'trabsh', 'traush', 'trashn', 'tragsh', 'trvash', 'tralsh', 'tratsh', 'tuash', 'trast', 'trmash', 'trksh', 'traosh', 'crash', 'trask', 'trpash', 'trqsh', 'trashv', 'traah', 'trasl', 'trhsh', 'trashw', 'trasj', 'tdrash', 'tyash', 'tkrash', 'frash', 'travh', 'trfash', 'tradh', 'traksh', 'trasyh', 'trnash', 'qtrash', 'tbrash'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("trash"))
# Out:
# {'troasu', 'tmrasph', 'strashu', 'flrash', 'wthrash', 'trrsth', 'trvaoh', 'btrasjh', 'tranhs', 'trfshl', 'ttsrash', 'gtwash', 'trdrh', 'trafszh', 'trahqs', 'trafsgh', 'torzash', 'rtask', 'itrasfh', 'drase', 'starsh', 'lrasxh', 'zrashb', 'brashe', 'traswoh', 'traslhj', 'traahd', 'ttasjh', 'tsraksh', 'trvfash', 'trasei', 'tlgash', 'tzrjsh', 'twrashl', 'ifrash', 'tvrsh', 'traisv', 'trkzh', 'vtrpsh', 'twasyh', 'trashhu', 'urhash', 'trxshi', 'tfrarsh', 'brakh', 'traasu', 'trasvwh', 'ttrush', 'trachd', 'hrashz', 'tuasjh', 'stbash', 'tmkrash', 'ptrasxh', 'xtreash', 'dtrashh', 'etrajh', 'taxh', 'tpaqsh', 'trashh', 'tragss', 'treash', 'ttfrash', 'trgxsh', 'vrashr', 'qtrashl', 'wraesh', 'tfrashs', 'tuhash', 'ptravsh', 'tnrfash', 'dtuash', 'tlashf', 'trzasmh', 'trjsht', 'thrajh', 'zrdash', 'jkrash', 'xtrgsh', 'tuysh', 'yjtrash', 'trxasc', 'tmashy', 'xtrjsh', 'travi', 'itrahs', 'tlrashy', 'tjasu', 'tsasrh', 'ftrdash', 'tgajh', 'yhrash', 'trashzi', 'tridh', 'teamsh', 'tlrsah', 'trbasht', 'trasdth', 'tswash', 'qerash', 'tjasfh', 'tragseh', 'tbasjh', 'htrasgh', 'mradh', 'rasp', 'trtshz', 'nrfsh', 'toradsh', 'trishc', 'tzhsh', 'rtrqash', 'trsauh', 'trqsd', 'nqtrash', 'toraseh', 'tyxrash', 'trsuash', 'tuavh', 'trajhx', 'twirash', 'lrasl', 'traqshk', 'tralf', 'srfash', 'jtrasc', 'trasxhv', 'hradh', 'tirabsh', 'ctrast', 'tlasf', 'ytrpash', 'trise', 'ftraeh', 'traqksh', 'traasrh', 'tcrgsh', 'trrsjh', 'vtrasoh', 'traisu', 'teacsh', 'trbfsh', 'tralsz', 'trabsv', 'twrajsh', 'prsah', 'tkrjash', 'nrvash', 'draszh', 'toranh', 'drasyh', 'mrasn', 'trnaysh', 'trashqj', 'tfraksh', 'vyrash', 'trlsash', 'gtsrash', 'trasthv', 'treashx', 'drasi', 'trqsih', 'thish', 'taaszh', 'ztryash', 'yrashz', 'srpash', 'trnayh', 'vryash', 'trapsy', 'trcesh', 'tprasho', 'tqrjash', 'trtasp', 'tdaoh', 'tnashm', 'trasol', 'ltrcash', 'trasgfh', 'trsxash', 'traqhz', 'ztrqash', 'tramshg', 'jtrasf', 'trwmsh', 'dtrqash', 'traysf', 'wrcash', 'tramfsh', 'tryajh', 'tralfh', 'trapssh', 'txashq', 'rrasw', 'txashe', 'twraph', 'trasiyh', 'dtraesh', 'trasyhd', 'itraseh', 'tpashj', 'trnasi', 'ftrashz', 'qraswh', 'tdrasz', 'dsash', 'turarsh', 'wrazh', 'timsh', 'trwshp', 'trastah', 'trqysh', 'trashdl', 'travsc', 'arsah', 'btraash', 'trpgsh', 'tradht', 'tharash', 'trabshh', 'ktrasa', 'trsdah', 'dtraxsh', 'tkah', 'yturash', 'trishj', 'ciash', 'trlshv', 'ntrasx', 'vralh', 'rtrvash', 'tranhb', 'trowsh', 'thrlash', 'terasm', 'trasjw', 'trafu', 'ktraxh', 'ptrashk', 'twansh', 'traazsh', 'tcrasv', 'trkshy', 'thmsh', 'ircsh', 'txrasz', 'trpah', 'tryashv', 'jtgrash', 'ntrashw', 'strsash', 'tidash', 'trashvg', 'traoshi', 'trsjah', 'tragshy', 'wtrqash', 'vtraih', 'trlahh', 'trkashz', 'hurash', 'ytrach', 'txzash', 'trcsk', 'trbsash', 'ktrazsh', 'rtrysh', 'tryasc', 'tpaeh', 'trarhd', 'ghrash', 'tryast', 'srlsh', 'orasc', 'toraxh', 'otrasho', 'trabsu', 'ztraah', 'tradhy', 'traxshg', 'grash', 'trareh', 'txashw', 'tvabh', 'tvrash', 'tgrasr', 'tfraeh', 'tlamh', 'arasa', 'gtrasd', 'trang', 'tvhsh', 'etrashj', 'yraqh', 'tcrauh', 'tizrash', 'irosh', 'trgaskh', 'trassdh', 'trabshg', 'traxhl', 'truaih', 'ctjrash', 'trashsz', 'tdraqsh', 'trxadsh', 'nramsh', 'traaq', 'tdramh', 'trdyash', 'tresj', 'tsrashm', 'tratshf', 'dtrvash', 'taresh', 'tzatsh', 'utramh', 'vrapsh', 'tsrrsh', 'trajsfh', 'tobash', 'traushf', 'tzraesh', 'jraosh', 'twjash', 'tiasyh', 'trdakh', 'traisha', 'lvrash', 'trmqh', 'trvqsh', 'trtasdh', 'tcrawh', 'trhazh', 'tzarsh', 'qrasj', 'trarsrh', 'ttasi', 'grafsh', 'nrasy', 'trznsh', 'trqashj', 'ptrayh', 'atrasvh', 'triih', 'tomsh', 'tsraoh', 'trkaosh', 'lraskh', 'ftrajsh', 'urask', 'twashi', 'drrash', 'rrast', 'trsvash', 'ltrashr', 'trmshl', 'tvasrh', 'turcsh', 'krasvh', 'tjrasph', 'trashhq', 'tkuash', 'trasxv', 'mrajh', 'jwtrash', 'trabshu', 'qrarsh', 'atsh', 'otraash', 'tbragh', 'trsaoh', 'tasv', 'trfahh', 'traqosh', 'jtraysh', 'qrasa', 'jtrasb', 'jtrrash', 'travx', 'traohy', 'tsasl', 'saash', 'trjashs', 'tarqh', 'trksrh', 'thzash', 'bthrash', 'treasyh', 'traez', 'trsashh', 'trzso', 'tzzash', 'trmashx', ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
#     print(f"{word} is already correctly spelt")  
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "famile"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
#   print(f"{correct} is suggested for {word}")
# Out:
# [('family', 6.24473100821182e-05)]

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r") as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters] 

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("auto.txt")

# %%
checker.check("sentense")
# Out:
# []

# %%
checker.check("doj")
# Out:
# [('do', 0.000905485996190714),
#  ('don', 0.00018734193024635463),
#  ('dog', 9.367096512317732e-05)]

# %%
checker.check("boll")
# Out:
# []

# %%
checker.check("everi")
# Out:
# [('every', 0.007493677209854186), ('ever', 0.003590720329721797)]

# %%
checker.check("waner")
# Out:
# [('water', 0.0003434602054516502), ('waver', 6.24473100821182e-05)]
